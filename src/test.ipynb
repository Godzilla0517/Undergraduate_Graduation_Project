# %%
import torch
a = torch.randn(32, 1, 64, 44)
print(a.shape)
# Out:
# torch.Size([32, 1, 64, 44])

# %%
from model_builder import CustomRNN
device = torch.device("cpu")
model = CustomRNN(64, 256, 2, 5, device)
b = a.reshape(-1, 44, 64).to(device)
c = model(b)
print(c.shape)
print(c)
# Out:
# torch.Size([32, 5])
# tensor([[-0.0814,  0.0515,  0.0111, -0.1064,  0.2185],
#         [-0.0575, -0.0585, -0.1414, -0.1744,  0.0193],
#         [-0.0153,  0.1097,  0.0579,  0.1263, -0.0892],
#         [ 0.0077,  0.2115, -0.1396, -0.0978,  0.1052],
#         [-0.1354, -0.1492, -0.0201, -0.0067, -0.2003],
#         [ 0.0115,  0.0405, -0.0576, -0.2018,  0.0645],
#         [ 0.0644,  0.1636, -0.1154, -0.1979, -0.0973],
#         [-0.1344,  0.0509, -0.0707, -0.0682,  0.1360],
#         [-0.2270,  0.0286, -0.1451,  0.0690, -0.0543],
#         [-0.1769,  0.0525,  0.0247,  0.0870, -0.1520],
#         [-0.1758, -0.1207, -0.1911,  0.0925,  0.1050],
#         [-0.2230,  0.0021, -0.0365,  0.1864,  0.0483],
#         [-0.2507, -0.0223, -0.1031,  0.1335,  0.0622],
#         [-0.0032, -0.0558,  0.1058, -0.1494, -0.0920],
#         [-0.0466, -0.0565,  0.0992, -0.0071, -0.0310],
#         [-0.0299,  0.0093,  0.0659,  0.0764, -0.1597],
#         [ 0.0834,  0.1485, -0.3431,  0.1379, -0.0460],
# ...

# %%
print(c.argmax(dim=1))
print(c.argmax(dim=1).shape)
# Out:
# tensor([4, 4, 3, 1, 3, 4, 1, 4, 3, 3, 4, 3, 3, 2, 2, 3, 1, 3, 1, 1, 1, 3, 4, 3,
#         3, 4, 0, 3, 4, 3, 1, 1])
# torch.Size([32])
